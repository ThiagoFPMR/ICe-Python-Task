# %%
#@title Setup
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/ICe-Python-Task

# !git config --global user.email "thiagofpmr@ufrn.edu.br"
# !git config --global user.name "ThiagoFPMR"

from getpass import getpass
password = getpass("Password: ")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/ICe-Python-Task
# Password: ··········

# %%
# !git add test.txt

# %%
# !git remote rm origin

# %%
# !git commit Git Version Control.ipynb
# Out:
# On branch master
# Changes not staged for commit:
# 	deleted:    Git Version Control.ipynb
# 	deleted:    test.txt
#
# Untracked files:
# 	a.ipynb
#
# no changes added to commit

# %%
# !git push origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 273 bytes | 136.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/ThiagoFPMR/ICe-Python-Task
#    da424b1..7bfe7a3  master -> master
